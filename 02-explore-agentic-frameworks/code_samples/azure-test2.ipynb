# %%
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from dotenv import load_dotenv
import os

load_dotenv(override=True)
key = os.environ["AZURE_OPENAI_API_KEY"]
endpoint = os.environ["PROJECT_ENDPOINT_FOUNDRY"]

project = AIProjectClient(
  endpoint=endpoint,  # Replace with your endpoint
  credential=DefaultAzureCredential())
# The AIProjectClient lets you access models, data, and services in your project.

# %%
from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential

print(endpoint)

project = AIProjectClient(
    endpoint=endpoint,
    credential=DefaultAzureCredential(),
)

models = project.get_openai_client(api_version="2024-10-21")
response = models.chat.completions.create(
    model="gpt-4o-deployed",
    messages=[
        {"role": "system", "content": "You are a helpful writing assistant"},
        {"role": "user", "content": "Write me a poem about flowers"},
    ],
)

print(response.choices[0].message.content)
# Out:
# https://akhil-mgemh6xt-swedencentral.services.ai.azure.com/api/projects/akhil-mgemh6xt-swedencentral_project
# **Whispers of the Bloom**
#
# In the quiet dawn, where shadows play,
# The flowers wake to greet the day.
# Veils of dew on petals rest,
# Nature's jewels at their best.
#
# A symphony of colors bright,
# Scarlets, golds, and purest white.
# Each blossom sings its silent tune,
# A hymn beneath the sun and moon.
#
# The roses speak of love's sweet ache,
# While daisies smile for joy's own sake.
# Lilies lift their heads in grace,
# Orchids bloom, a sacred space.
#
# Sunflowers chase the warming rays,
# Through endless skies, they tilt and sway.
# And violets shyly hug the earth,
# A modest gift of quiet mirth.
#
# Oh, fleeting blooms, so soft, so rare,
# You teach us life with tender care.
# To cherish beauty where it's found,
# Before it fades into the ground.
#
# For petals fall, and time moves on,
# Yet blossoms linger, even gone.
# In hearts, in dreams, their colors stay,
# A timeless love that won't decay.

# %%
### Creating an agent - very simple stuff

from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential
from azure.ai.agents.models import ListSortOrder, FilePurpose

project = AIProjectClient(
    endpoint=endpoint,
    credential=DefaultAzureCredential(),
)

agent = project.agents.create_agent(
    model="gpt-4o-deployed",
    name="my-agent",
    instructions="You are a helpful writing assistant")

thread = project.agents.threads.create()
message = project.agents.messages.create(
    thread_id=thread.id, 
    role="user", 
    content="Write me a poem about flowers")

run = project.agents.runs.create_and_process(thread_id=thread.id, agent_id=agent.id)
if run.status == "failed":
    # Check if you got "Rate limit is exceeded.", then you want to get more quota
    print(f"Run failed: {run.last_error}")

# Get messages from the thread
messages = project.agents.messages.list(thread_id=thread.id)

# Get the last message from the sender
messages = project.agents.messages.list(thread_id=thread.id, order=ListSortOrder.ASCENDING)
for message in messages:
    if message.run_id == run.id and message.text_messages:
        print(f"{message.role}: {message.text_messages[-1].text.value}")

# Delete the agent once done
project.agents.delete_agent(agent.id)
print("Deleted agent")
# Out:
# MessageRole.AGENT: **The Whisper of Flowers**
#
# In the cradle of earth, where sunlight plays,
# Burst forth the blooms in vibrant arrays.
# Petals of fire, petals of frost,
# Each tells a story, no beauty is lost.
#
# Roses blush in crimson hues,
# Whispering secrets with morning dew.
# Tulips stand proud in golden light,
# Dreams unfold as day turns to night.
#
# The lilacs hum a fragrant tune,
# Underneath the watchful moon.
# Daisies dance in fields of green,
# Smiling wide where peace is gleaned.
#
# Orchids wear their regal crown,
# Draped in silk, where love is found.
# Sunflowers stretch toward sky ablaze,
# Following warmth through endless days.
#
# Flowers speak without a voice,
# A gentle touch, a quiet choice.
# They bloom for poets, they bloom for hearts,
# A fleeting beauty, life's purest art.
#
# Oh, garden of wonder, oh, meadow divine,
# Each petal a moment, a fragment in time.
# In your soft blossoms, life's truth reveals,
# Flowers heal what the soul conceals.
# Deleted agent
